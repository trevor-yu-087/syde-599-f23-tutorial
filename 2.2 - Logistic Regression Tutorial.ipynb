# %%
# For Colab
# !git clone https://github.com/trevor-yu-087/syde-599-f23-tutorial.git
# DATA_PATH = "syde-599-f23-tutorial/data/logistic-regression-data.pkl"

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import pickle

# %%
with open("data/logistic-regression-data.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['training_x', 'training_y', 'validation_x', 'validation_y'])

# %% [markdown]
# # Section 1: Logistic Regression with Scikit-Learn
# In this tutorial, we will use scikit-learn Linear Regression to do binary classification. The goal is again to get familiar with the typical machine learning workflow.

# %%
# By convention, 2D data (matrices) uses capital letters, while 1D data (vectors) uses lower case letters
X_train = data["training_x"]
y_train = data["training_y"]
X_val = data["validation_x"]
y_val = data["validation_y"]

# %%
# TODO: Plot features at index 2 and 3

plt.xlabel("Feature 2")
plt.ylabel("Feature 3")
plt.show()

# %% [markdown]
# [Scikit-learn Logistic Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
from sklearn.linear_model import LogisticRegression

# TODO: Instantiate model

# %%
# TODO: Fit model on training data
# Out:
# LogisticRegression()

# %%
# TODO: Score model on the training and validation sets
train_acc = None
val_acc = None

print(f"Training accuracy: {train_acc*100:.2f}%")
print(f"Validation accuracy: {val_acc*100:.2f}%")
# Out:
# Training accuracy: 94.67%
# Validation accuracy: 92.00%

# %%
# TODO: Get the probabilities for class 0 and class 1
probs = None
# Out:
# array([[0.76571008, 0.23428992],
#        [0.03807589, 0.96192411],
#        [0.69069949, 0.30930051],
#        [0.00828769, 0.99171231],
#        [0.06775818, 0.93224182],
#        [0.02522851, 0.97477149],
#        [0.79628948, 0.20371052],
#        [0.4505042 , 0.5494958 ],
#        [0.03493644, 0.96506356],
#        [0.12822052, 0.87177948],
#        [0.12226014, 0.87773986],
#        [0.24500328, 0.75499672],
#        [0.06583504, 0.93416496],
#        [0.77271386, 0.22728614],
#        [0.99475053, 0.00524947],
#        [0.980599  , 0.019401  ],
#        [0.60895504, 0.39104496],
#        [0.93092402, 0.06907598],
#        [0.41005703, 0.58994297],
#        [0.86877299, 0.13122701],
#        [0.99480335, 0.00519665],
#        [0.0995938 , 0.9004062 ],
#        [0.94864129, 0.05135871],
#        [0.2930718 , 0.7069282 ],
#        [0.94638977, 0.05361023],
#        [0.99724104, 0.00275896],
#        [0.71764081, 0.28235919],
#        [0.31325143, 0.68674857],
#        [0.05300085, 0.94699915],
#        [0.51288567, 0.48711433],
#        [0.27184233, 0.72815767],
#        [0.04140487, 0.95859513],
#        [0.04055352, 0.95944648],
#        [0.00225712, 0.99774288],
#        [0.24500328, 0.75499672],
#        [0.49671469, 0.50328531],
#        [0.79808161, 0.20191839],
#        [0.62986753, 0.37013247],
#        [0.23494226, 0.76505774],
#        [0.06400147, 0.93599853],
#        [0.84476947, 0.15523053],
#        [0.19225612, 0.80774388],
#        [0.96534088, 0.03465912],
#        [0.8189143 , 0.1810857 ],
#        [0.79723412, 0.20276588],
#        [0.90597118, 0.09402882],
#        [0.97214523, 0.02785477],
#        [0.89845167, 0.10154833],
#        [0.9461224 , 0.0538776 ],
#        [0.85929555, 0.14070445],
#        [0.17347015, 0.82652985],
#        [0.01218125, 0.98781875],
#        [0.83405832, 0.16594168],
#        [0.78465766, 0.21534234],
#        [0.81439058, 0.18560942],
#        [0.0107057 , 0.9892943 ],
#        [0.9046239 , 0.0953761 ],
#        [0.79787839, 0.20212161],
#        [0.84020061, 0.15979939],
#        [0.04157488, 0.95842512],
#        [0.9906126 , 0.0093874 ],
#        [0.9880344 , 0.0119656 ],
#        [0.16580638, 0.83419362],
#        [0.03099467, 0.96900533],
#        [0.15579257, 0.84420743],
#        [0.01967089, 0.98032911],
#        [0.97371782, 0.02628218],
#        [0.232481  , 0.767519  ],
#        [0.98436478, 0.01563522],
#        [0.13223804, 0.86776196],
#        [0.97639856, 0.02360144],
#        [0.99366019, 0.00633981],
#        [0.94536349, 0.05463651],
#        [0.21491296, 0.78508704],
#        [0.07493247, 0.92506753]])

# %%
# TODO: Plot the class 0 probabilities against the class 1 probabilities
true_probs = None
false_probs = None

plt.hist([true_probs, false_probs], bins=10)
plt.xlabel('Predicted probability')
plt.ylabel('Count')
plt.title('Training data')
plt.show()

# %%
# TODO: Plot the probabilities for the validation data

# %%
plt.hist([true_probs_val, false_probs_val], bins=10)
plt.xlabel('Predicted probability')
plt.ylabel('Count')
plt.title('Validation data')
plt.show()

# %% [markdown]
# # Section 2: Logistic Regression in Torch
#
# This section is optional, but provided to get a sense of how torch can be used to the same kind of model, but with more upfront work. If you have familiarity with torch, try to code up logistic regression on your own!

# %%
from torch import nn
from sklearn.metrics import accuracy_score

class LogReg(nn.Module):
    def __init__(self, num_features=2):
        super().__init__()
        # TODO: Setup linear layer for the model

    def forward(self, x):
        # TODO: Apply logistic regression model in forward
        return x

# %%
# Must convert data to torch FloatTensor for neural networks
X_train = torch.FloatTensor(X_train)
y_train = torch.FloatTensor(y_train.astype(np.float32)).unsqueeze(-1)

# %%
# TODO: Setup loss function for logistic regression
loss_function = nn.BCELoss()
#####
NUM_STEPS = 200
model = LogReg(X_train.shape[-1])
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1)
# Out:
# BCE Loss at epoch 0: 0.622
# Accuracy score at epoch 0: 0.520
# BCE Loss at epoch 10: 0.528
# Accuracy score at epoch 10: 0.973
# BCE Loss at epoch 20: 0.503
# Accuracy score at epoch 20: 0.960
# BCE Loss at epoch 30: 0.482
# Accuracy score at epoch 30: 0.960
# BCE Loss at epoch 40: 0.463
# Accuracy score at epoch 40: 0.960
# BCE Loss at epoch 50: 0.445
# Accuracy score at epoch 50: 0.960
# BCE Loss at epoch 60: 0.429
# Accuracy score at epoch 60: 0.960
# BCE Loss at epoch 70: 0.415
# Accuracy score at epoch 70: 0.960
# BCE Loss at epoch 80: 0.401
# Accuracy score at epoch 80: 0.960
# BCE Loss at epoch 90: 0.389
# Accuracy score at epoch 90: 0.960
# BCE Loss at epoch 100: 0.378
# Accuracy score at epoch 100: 0.960
# BCE Loss at epoch 110: 0.367
# Accuracy score at epoch 110: 0.960
# BCE Loss at epoch 120: 0.357
# Accuracy score at epoch 120: 0.960
# BCE Loss at epoch 130: 0.348
# Accuracy score at epoch 130: 0.960
# BCE Loss at epoch 140: 0.340
# Accuracy score at epoch 140: 0.960
# BCE Loss at epoch 150: 0.332
# Accuracy score at epoch 150: 0.960
# BCE Loss at epoch 160: 0.324
# Accuracy score at epoch 160: 0.973
# BCE Loss at epoch 170: 0.317
# Accuracy score at epoch 170: 0.973
# BCE Loss at epoch 180: 0.311
# Accuracy score at epoch 180: 0.973
# BCE Loss at epoch 190: 0.304
# Accuracy score at epoch 190: 0.973

# %%
# TODO: Complete the training loop, pass all the training data each step
losses = []
accs = []

for i in range(NUM_STEPS):
    continue

# %%
# Plot the training curves, final accuracy should be comparable to sklearn model
plt.plot(losses)
plt.ylabel("BCE Loss")
plt.twinx()
plt.plot(accs, c="C1")
plt.ylabel("Train accuracy")
plt.show()
